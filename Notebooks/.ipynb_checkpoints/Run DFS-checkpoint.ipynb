# %%
import sys
sys.path.append('../src')

import process_lineup

# %%
instance = process_lineup.yahoo_dfs()
# Out:
# [2024-11-11 12:45:46,104 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# 2024-11-11 12:45:46,104 - DEBUG - Checking
# [2024-11-11 12:45:46,105 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 679.9501023292542
# 2024-11-11 12:45:46,105 - DEBUG - ELAPSED TIME : 679.9501023292542
# [2024-11-11 12:45:46,106 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# 2024-11-11 12:45:46,106 - DEBUG - TOKEN IS STILL VALID

# %%
output = instance.run()
# Out:
# 2024-11-11 12:45:47,576 - INFO - yahoo players imported
# 2024-11-11 12:46:35,087 - INFO - NBA Teams Processed
# 2024-11-11 12:46:35,089 - INFO - Processing DeMar DeRozan for game logs
# 2024-11-11 12:46:35,852 - INFO - Processing Alex Len for game logs
# 2024-11-11 12:46:36,719 - INFO - Processing Doug McDermott for game logs
# 2024-11-11 12:46:36,733 - ERROR - Error processing Doug McDermott
# 2024-11-11 12:46:36,734 - INFO - Processing Trey Lyles for game logs
# 2024-11-11 12:46:37,463 - INFO - Processing Domantas Sabonis for game logs
# 2024-11-11 12:46:38,246 - INFO - Processing De'Aaron Fox for game logs
# 2024-11-11 12:46:39,073 - INFO - Processing Malik Monk for game logs
# 2024-11-11 12:46:39,827 - INFO - Processing Kevin Huerter for game logs
# 2024-11-11 12:46:40,542 - INFO - Processing Jordan McLaughlin for game logs
# 2024-11-11 12:46:42,229 - INFO - Processing Mason Jones for game logs
# 2024-11-11 12:46:43,021 - INFO - Skipping Mason Jones due to playing less than 5
# ...
