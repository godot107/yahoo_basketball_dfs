# %%
import sys
sys.path.append('../src')

import process_lineup

# %%
instance = process_lineup.yahoo_dfs()
# Out:
# [2024-11-12 08:21:14,326 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# 2024-11-12 08:21:14,326 - DEBUG - Checking
# [2024-11-12 08:21:14,334 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 71208.18003606796
# 2024-11-12 08:21:14,334 - DEBUG - ELAPSED TIME : 71208.18003606796
# [2024-11-12 08:21:14,336 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN HAS EXPIRED
# 2024-11-12 08:21:14,336 - DEBUG - TOKEN HAS EXPIRED
# [2024-11-12 08:21:14,336 DEBUG] [yahoo_oauth.oauth.refresh_access_token] REFRESHING TOKEN
# 2024-11-12 08:21:14,336 - DEBUG - REFRESHING TOKEN

# %%
output = instance.run()
# Out:
# 2024-11-12 08:21:15,973 - INFO - yahoo players imported
# 2024-11-12 08:21:57,259 - INFO - NBA Teams Processed
# 2024-11-12 08:21:57,260 - INFO - Processing Garrett Temple for game logs
# 2024-11-12 08:21:58,045 - INFO - Skipping Garrett Temple due to playing less than 5 games
# 2024-11-12 08:21:58,045 - INFO - Processing Kelly Olynyk for game logs
# 2024-11-12 08:21:58,798 - INFO - Skipping Kelly Olynyk due to playing less than 5 games
# 2024-11-12 08:21:58,799 - INFO - Processing Jakob Pöltl for game logs
# 2024-11-12 08:21:59,485 - INFO - Processing Chris Boucher for game logs
# 2024-11-12 08:22:00,227 - INFO - Processing Bruce Brown for game logs
# 2024-11-12 08:22:00,975 - INFO - Skipping Bruce Brown due to playing less than 5 games
# 2024-11-12 08:22:00,976 - INFO - Processing RJ Barrett for game logs
# 2024-11-12 08:22:01,652 - INFO - Processing Bruno Fernando for game logs
# 2024-11-12 08:22:03,226 - INFO - Processing Immanuel Quickley for game logs
# ...
